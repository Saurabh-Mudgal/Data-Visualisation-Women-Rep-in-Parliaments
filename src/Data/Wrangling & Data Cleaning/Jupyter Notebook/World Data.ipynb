# %%
import pandas as pd

wb_data = pd.read_csv(r"C:\Users\saura\OneDrive\Desktop\Strait Times\Data\Worldwide\World_Data.csv")

# %%
wb_data.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Proportion of seats held by women in national ...  SG.GEN.PARL.ZS   NaN
# 1  Proportion of seats held by women in national ...  SG.GEN.PARL.ZS   NaN
# 2  Proportion of seats held by women in national ...  SG.GEN.PARL.ZS   NaN
# 3  Proportion of seats held by women in national ...  SG.GEN.PARL.ZS   NaN
# 4  Proportion of seats held by women in national ...  SG.GEN.PARL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  25.246212  25.022278  25.915055
# ...

# %%
sg_data = pd.read_csv(r"C:\Users\saura\OneDrive\Desktop\Strait Times\Data\SG\seatsByWomen.csv")

sg_data.head()
# Out:
#    1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  2014  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  27.7
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  36.8
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  20.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  50.0
#
#    2015  2016  2017  2018   2019  Country Name  Country Code  \
# 0   NaN   NaN   NaN   NaN    NaN         Aruba           ABW
# 1  27.7  27.7  27.7  27.7  27.87   Afghanistan           AFG
# 2  36.8  36.8  38.2  30.5  30.00        Angola           AGO
# 3  20.7  22.9  27.9  27.9  29.51       Albania           ALB
# 4  39.3  32.1  32.1  32.1  50.00       Andorra           AND
#
#                                       Indicator Name  Indicator Code
# 0  Proportion of seats held by women in national ...  SG.GEN.PARL.ZS
# ...

# %%
world_distribution = pd.read_csv(r"C:\Users\saura\OneDrive\Desktop\Strait Times\Data\SG\seatsByWomen_Cleaned-Wrangled.csv")

world_distribution
# Out:
#                     Country Name  1999  2000  2001  2002  2003  2004  2005  \
# 0                          Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    Africa Eastern and Southern  12.5  14.8  15.4  16.7  16.7  17.4  19.3
# 2                    Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN  27.3
# 3     Africa Western and Central   NaN   6.8   7.4   7.9   9.0  10.1  10.7
# 4                         Angola  15.5  15.5  15.5  15.5  15.5  15.0  15.0
# ..                           ...   ...   ...   ...   ...   ...   ...   ...
# 261                       Kosovo   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262                  Yemen, Rep.   0.7   0.7   0.7   0.7   0.3   0.3   0.3
# 263                 South Africa  30.0  29.8  29.8  29.8  29.8  32.8  32.8
# 264                       Zambia  10.1  10.1  10.1  12.0  12.0  12.0  12.7
# 265                     Zimbabwe  14.0   9.3  10.0  10.0  10.0  10.0  16.0
#
# ...

# %%
pd.set_option('display.max_rows', df.shape[0]+1)

df = pd.read_csv(r"C:\Users\saura\OneDrive\Desktop\Strait Times\Data\heatmap.csv")

df
# Out:
#                                           Country Name  Percentage
# 0                          Africa Eastern and Southern        30.1
# 1                                          Afghanistan        27.0
# 2                           Africa Western and Central        16.3
# 3                                               Angola        30.0
# 4                                              Albania        29.5
# 5                                              Andorra        46.4
# 6                                           Arab World        19.5
# 7                                 United Arab Emirates        50.0
# 8                                            Argentina        40.9
# 9                                              Armenia        23.5
# 10                                 Antigua and Barbuda        11.1
# 11                                           Australia        30.5
# 12                                             Austria        39.3
# ...
